# %% [markdown]
# # Nearest Neighbor Classification
#
# ## Properties
#
# NN is a lazy learner, it does not require model building,
# this makes it costly at prediction time.
#
# DT are constrainted to rectilinear boundaries,
# while NN can produce arbitrarily shaped boundaries.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from dataclasses import dataclass

@dataclass
class DataPoint:
    attributes: np.ndarray
    label: str

# %%
x = DataPoint(attributes=np.array([1, 2, 3]), label="positive")
y = DataPoint(attributes=np.array([-1, -2, -3]), label="negative")

# %%
cov = np.array([[5, 4], [4, 7]])
data = np.random.multivariate_normal(mean=[0, 0], cov=cov, size=100)
plt.scatter(data[:, 0], data[:, 1])

# %%
def knn_classify
